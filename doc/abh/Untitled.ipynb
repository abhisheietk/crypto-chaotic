# %%
# %pylab inline
import numpy as np
import matplotlib as ml
import matplotlib.pyplot as plt
import mandel as md

nn = 1000
re = np.linspace(-2.1,1,nn)
im = np.linspace(-1.3,1.3,nn+1)

out = md.calc_num_iter(re, im)

fig = plt.figure(figsize=(5, 10))

ax = fig.add_subplot(111)
ax.set_title('colorMap')
plt.imshow(out)
ax.set_aspect('equal')

#cax = fig.add_axes([0.12, 0.1, 0.78, 0.8])
#cax.get_xaxis().set_visible(False)
#cax.get_yaxis().set_visible(False)
#cax.patch.set_alpha(0)
#cax.set_frame_on(False)
#plt.colorbar(orientation='vertical')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['rc', 'linalg', 'draw_if_interactive', 'random', 'power', 'info', 'fft']
# `%matplotlib` prevents importing * from pylab and numpy
# WARNING: pylab import has clobbered these variables: ['rc', 'linalg', 'draw_if_interactive', 'random', 'power', 'info', 'fft']
# `%matplotlib` prevents importing * from pylab and numpy
# WARNING: pylab import has clobbered these variables: ['rc', 'linalg', 'draw_if_interactive', 'random', 'power', 'info', 'fft']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# %pylab inline
from pylab import *
from matplotlib import rc, rcParams
import matplotlib.pyplot as plt

rc('text',usetex=True)
rc('font',**{'family':'serif','serif':['Computer Modern']})


#  Import the data from a text file and save as a 2D matrix.
#dataMatrix1 = genfromtxt('winavrg.dat')
dataMatrix1 = genfromtxt('signal_recovered.dat')

# Slice out required abscissae and ordinate vectors.

y1 = dataMatrix1[:,0]
y2 = dataMatrix1[:,1]
x = range(len(y1))

plt.figure(figsize=(100, 100))

plt.plot(x,y1)
plt.plot(x,y2)
plt.show()
